# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Problem: Generate stimela script
#
# The first problem is to see if we can get the agents to generate a stimela script that can:
#
# 1. Locate the measurement set and gets its path
# 2. Perform flagging using `tricolour`
# 3. Perform self-cal using `QuartiCal`
# 4. Perform full-imaging using `WSClean`

# %%
user_prompt = """Generate a data reduction script for this """

# %% [markdown]
# # Version 1: Simple
#
# Here we will create a simple stimela script generation agent with nothing included, only a supervisor LLM.

# %%
from pydantic_ai import Agent
from pydantic_graph import GraphRunContext, GraphRun, End, BaseNode



class GenerateStimela(BaseNode[])
